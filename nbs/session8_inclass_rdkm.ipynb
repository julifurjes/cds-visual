# %% [markdown]
# # Introducing CNNS with TensorFlow
#
#
# In this notebook, we're going to see how we can use ```TensorFlow``` to build convolutional neural networks to work with colour image data.

# %% [markdown]
# ## Load libraries

# %%
# data tools
import os
import numpy as np
import matplotlib.pyplot as plt

# sklearn tools
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report

# tf tools
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, 
                                     MaxPooling2D, 
                                     Activation, 
                                     Flatten, 
                                     Dense)
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K
# Out:
# 2023-03-31 13:29:21.040638: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-03-31 13:29:21.115601: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-03-31 13:29:21.116925: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-31 13:29:22.114805: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# __Define plotting function__

# %%
def plot_history(H, epochs):
    plt.style.use("seaborn-colorblind")

    plt.figure(figsize=(12,6))
    plt.subplot(1,2,1)
    plt.plot(np.arange(0, epochs), H.history["loss"], label="train_loss")
    plt.plot(np.arange(0, epochs), H.history["val_loss"], label="val_loss", linestyle=":")
    plt.title("Loss curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.tight_layout()
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(np.arange(0, epochs), H.history["accuracy"], label="train_acc")
    plt.plot(np.arange(0, epochs), H.history["val_accuracy"], label="val_acc", linestyle=":")
    plt.title("Accuracy curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# __Load cifar10 data__

# %% [markdown]
# We first want to load the ```cifar-10``` dataset, normalize the values, and then binarize the labels.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 7s 0us/step

# %% [markdown]
# **Question:** As an experiment, see what happens if you try to train the model with un-scaled images. Does it affect performance?

# %%
X_train = X_train/255
X_test = X_test/255

# %%
# create one-hot encodings
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)

# %% [markdown]
# We'll also manually create a list of labels for when we come to print the classification report later.

# %%
# initialize label names for CIFAR-10 dataset
label_names = ["airplane", "automobile", 
              "bird", "cat", 
              "deer", "dog", 
              "frog", "horse", 
              "ship", "truck"]

# %% [markdown]
# ## ShallowNet

# %% [markdown]
# We're going to begin by creating one of the simplest CNN architectures with only a single convolutional layer. This type of architecture is known as the ShallowNet architecture:
# >INPUT => CONV => ReLU => FC

# %%
#initalise model
model = Sequential()

# define CONV => ReLU
model.add(Conv2D(32, 
                (3,3),
                padding = "same",
                input_shape = (32, 32, 3)))
model.add(Activation("relu"))
          
# FC classifier
model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))
model.add(Dense(10))
model.add(Activation("softmax"))

# %% [markdown]
# __Compile model__

# %% [markdown]
# We then compile our model using some of the same arguments we've already seen in different contexts.

# %%
sgd = SGD(learning_rate =.001)
model.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])

# %% [markdown]
# __Model summary__

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 128)               4194432
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
#  activation_2 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 4,196,618
# Trainable params: 4,196,618
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Plot model__

# %%
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# __Train model__

# %% [markdown]
# Finally, we train the model on the data and get our predictions.

# %%
H = model.fit(X_train, 
              y_train,
              validation_split=0.1,
              batch_size=32,
              epochs=20,
              verbose=1)
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 11s 7ms/step - loss: 2.0794 - accuracy: 0.2659 - val_loss: 1.9397 - val_accuracy: 0.3246
# Epoch 2/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.8573 - accuracy: 0.3527 - val_loss: 1.8279 - val_accuracy: 0.3590
# Epoch 3/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.7778 - accuracy: 0.3801 - val_loss: 1.7784 - val_accuracy: 0.3792
# Epoch 4/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.7224 - accuracy: 0.4009 - val_loss: 1.7322 - val_accuracy: 0.3960
# Epoch 5/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.6789 - accuracy: 0.4157 - val_loss: 1.7044 - val_accuracy: 0.3834
# Epoch 6/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.6370 - accuracy: 0.4294 - val_loss: 1.6531 - val_accuracy: 0.4304
# Epoch 7/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5976 - accuracy: 0.4431 - val_loss: 1.5989 - val_accuracy: 0.4452
# Epoch 8/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5610 - accuracy: 0.4555 - val_loss: 1.5790 - val_accuracy: 0.4494
# Epoch 9/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5268 - accuracy: 0.4653 - val_loss: 1.5829 - val_accuracy: 0.4400
# Epoch 10/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4943 - accuracy: 0.4779 - val_loss: 1.5245 - val_accuracy: 0.4634
# Epoch 11/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4637 - accuracy: 0.4879 - val_loss: 1.4932 - val_accuracy: 0.4702
# Epoch 12/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4359 - accuracy: 0.4964 - val_loss: 1.4764 - val_accuracy: 0.4798
# Epoch 13/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4119 - accuracy: 0.5049 - val_loss: 1.4924 - val_accuracy: 0.4666
# Epoch 14/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3880 - accuracy: 0.5134 - val_loss: 1.4388 - val_accuracy: 0.4878
# Epoch 15/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3658 - accuracy: 0.5216 - val_loss: 1.3917 - val_accuracy: 0.5066
# Epoch 16/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3456 - accuracy: 0.5287 - val_loss: 1.3854 - val_accuracy: 0.5170
# Epoch 17/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3273 - accuracy: 0.5332 - val_loss: 1.4260 - val_accuracy: 0.4958
# Epoch 18/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3095 - accuracy: 0.5403 - val_loss: 1.3888 - val_accuracy: 0.5062
# Epoch 19/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.2916 - accuracy: 0.5460 - val_loss: 1.3414 - val_accuracy: 0.5146
# Epoch 20/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.2763 - accuracy: 0.5530 - val_loss: 1.3127 - val_accuracy: 0.5352

# %% [markdown]
# __Evaluate model__

# %%
predictions = model.predict(X_test, batch_size=32)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
print(classification_report(y_test.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=label_names))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.54      0.65      0.59      1000
#   automobile       0.60      0.74      0.66      1000
#         bird       0.50      0.29      0.37      1000
#          cat       0.35      0.45      0.40      1000
#         deer       0.49      0.41      0.45      1000
#          dog       0.48      0.38      0.43      1000
#         frog       0.49      0.67      0.57      1000
#        horse       0.61      0.56      0.58      1000
#         ship       0.67      0.62      0.64      1000
#        truck       0.62      0.55      0.58      1000
#
#     accuracy                           0.53     10000
#    macro avg       0.54      0.53      0.53     10000
# weighted avg       0.54      0.53      0.53     10000

# %% [markdown]
# We can also use the ```plot_history()``` function available from ```TensorFlow``` to see how our model performs during training.
#
# These plots can tell us *a lot* about whether a model is under- or over-fiting the data. You read more at [this fantastic blog post](https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/).
#
# Other useful blogs are [here](https://rstudio-conf-2020.github.io/dl-keras-tf/notebooks/learning-curve-diagnostics.nb.html) and there's a good video overview [here](https://youtu.be/p3CcfIjycBA).

# %%
plot_history(H, 20)
# Out:
# /tmp/ipykernel_2821/3716877966.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-colorblind")

# %% [markdown]
# ## LeNet

# %% [markdown]
# Next, we'll look at a slightly more complicated CNN architecture, known as ```LeNet``` after its creator Yann LeCun, who is now Chief AI Scientist at Meta. You can read more [here](https://en.wikipedia.org/wiki/LeNet).
# >INPUT => CONV => ReLU => MAXPOOL => CONV => ReLU => MAXPOOL => FC => ReLU => FC

# %% [markdown]
# __Define model__

# %%
# define model
model = Sequential()

# first set of layers CONV => RELU => MAXPOOL
model.add(Conv2D(32, (3,3),
                 padding="same",
                 input_shape=(32,32,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2),
                       strides = (2,2)))

# second set of layers CONV => RELU => MAXPOOL
model.add(Conv2D(50, (5,5),
                 padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2),
                       strides = (2,2)))

# FC => RELU
model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))

# softmax classifier
model.add(Dense(10))
model.add(Activation("softmax"))

# %% [markdown]
# __Compile model__

# %%
sgd = SGD(learning_rate=0.001)
model.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])

# %% [markdown]
# __Model summary__

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        896
#
#  activation_3 (Activation)   (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 50)        40050
#
#  activation_4 (Activation)   (None, 16, 16, 50)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 50)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 3200)              0
#
#  dense_2 (Dense)             (None, 128)               409728
#
#  activation_5 (Activation)   (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
#  activation_6 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 451,964
# Trainable params: 451,964
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Train model__

# %%
# train model
H = model.fit(X_train, 
              y_train, 
              validation_split=0.1, 
              batch_size=32,
              epochs=20,
              verbose=1)
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 15s 10ms/step - loss: 2.2330 - accuracy: 0.2024 - val_loss: 2.1417 - val_accuracy: 0.2728
# Epoch 2/20
# 1407/1407 [==============================] - 14s 10ms/step - loss: 2.0471 - accuracy: 0.2804 - val_loss: 1.9859 - val_accuracy: 0.2940
# Epoch 3/20
# 1407/1407 [==============================] - 14s 10ms/step - loss: 1.9425 - accuracy: 0.3155 - val_loss: 1.9133 - val_accuracy: 0.3272
# Epoch 4/20
# 1407/1407 [==============================] - 14s 10ms/step - loss: 1.8810 - accuracy: 0.3400 - val_loss: 1.8630 - val_accuracy: 0.3254
# Epoch 5/20
# 1407/1407 [==============================] - 14s 10ms/step - loss: 1.8211 - accuracy: 0.3636 - val_loss: 1.8827 - val_accuracy: 0.3398
# Epoch 6/20
# 1407/1407 [==============================] - 14s 10ms/step - loss: 1.7618 - accuracy: 0.3832 - val_loss: 1.7409 - val_accuracy: 0.3862
# Epoch 7/20
# 1407/1407 [==============================] - 14s 10ms/step - loss: 1.7025 - accuracy: 0.4034 - val_loss: 1.6747 - val_accuracy: 0.4060
# Epoch 8/20
# 1407/1407 [==============================] - 14s 10ms/step - loss: 1.6438 - accuracy: 0.4219 - val_loss: 1.6524 - val_accuracy: 0.4124
# Epoch 9/20
# 1407/1407 [==============================] - 14s 10ms/step - loss: 1.5901 - accuracy: 0.4398 - val_loss: 1.6943 - val_accuracy: 0.3926
# Epoch 10/20
# 1407/1407 [==============================] - 14s 10ms/step - loss: 1.5456 - accuracy: 0.4537 - val_loss: 1.5689 - val_accuracy: 0.4416
# Epoch 11/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.5079 - accuracy: 0.4676 - val_loss: 1.6015 - val_accuracy: 0.4132
# Epoch 12/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.4766 - accuracy: 0.4780 - val_loss: 1.4779 - val_accuracy: 0.4704
# Epoch 13/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.4504 - accuracy: 0.4866 - val_loss: 1.4653 - val_accuracy: 0.4764
# Epoch 14/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.4263 - accuracy: 0.4973 - val_loss: 1.4523 - val_accuracy: 0.4726
# Epoch 15/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.4053 - accuracy: 0.5065 - val_loss: 1.4173 - val_accuracy: 0.4954
# Epoch 16/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.3866 - accuracy: 0.5104 - val_loss: 1.4145 - val_accuracy: 0.4942
# Epoch 17/20
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.3671 - accuracy: 0.5209 - val_loss: 1.3906 - val_accuracy: 0.5028
# Epoch 18/20
# 1407/1407 [==============================] - 20s 14ms/step - loss: 1.3491 - accuracy: 0.5259 - val_loss: 1.3995 - val_accuracy: 0.5042
# Epoch 19/20
# 1407/1407 [==============================] - 25s 18ms/step - loss: 1.3320 - accuracy: 0.5330 - val_loss: 1.3870 - val_accuracy: 0.5020
# Epoch 20/20
# 1407/1407 [==============================] - 25s 18ms/step - loss: 1.3157 - accuracy: 0.5360 - val_loss: 1.3486 - val_accuracy: 0.5180

# %%
plot_history(H,20)
# Out:
# /tmp/ipykernel_2821/3716877966.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-colorblind")

# %%
predictions = model.predict(X_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=label_names))
# Out:
# 313/313 [==============================] - 2s 6ms/step
#               precision    recall  f1-score   support
#
#     airplane       0.60      0.55      0.57      1000
#   automobile       0.63      0.68      0.65      1000
#         bird       0.48      0.26      0.34      1000
#          cat       0.47      0.18      0.26      1000
#         deer       0.36      0.58      0.45      1000
#          dog       0.49      0.41      0.45      1000
#         frog       0.57      0.65      0.60      1000
#        horse       0.49      0.67      0.57      1000
#         ship       0.54      0.77      0.63      1000
#        truck       0.66      0.47      0.55      1000
#
#     accuracy                           0.52     10000
#    macro avg       0.53      0.52      0.51     10000
# weighted avg       0.53      0.52      0.51     10000
